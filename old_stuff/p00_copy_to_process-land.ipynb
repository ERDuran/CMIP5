# %%
'''
This file concatenates CMIP5 monthly chunks of data for the historical and RCP8.5 experiments located in 
/g/data1/ua6/DRSv2/CMIP5/
and places the concatenated complete runs in
/g/data/e14/erd561/CMIP5/

This code needs to be run in python 3 and uses the NCO toolkit
module load python3
module load nco

Earl Duran 
created: 23-Feb-18
e.duran@unsw.edu.au
'''

import os
import subprocess

# %%
CMIP5_dir = '/Users/earl/Desktop/Yang'

my_dir = '/g/data/e14/erd561/CMIP5/process-land'

#os.chdir(CMIP5_dir)
#models_list = str(os.system('ls'))
models_list = sorted(os.listdir(CMIP5_dir))

# %%
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-44-e1ec24aa1795> in <module>()
#       4     stdout=subprocess.PIPE).communicate()[0]
#       5
# ----> 6 print(time[0])
#       7
#       8 x = int(time[0:-4]) /12/365
#
# IndexError: index out of range

# %%
#print(models_list)

experiment = 'historical'

frequency = 'mon'

medium = 'ocean'

initial_cond = 'r1i1p1'

SST = 'tos'

#tau = 'tos'

version = 'latest'

start_time = 186101

finish_time = 200512

for model in models_list:
    pls = os.listdir(CMIP5_dir + '/' + model)
    if experiment in pls:
        pls = os.listdir(CMIP5_dir + '/' + model + '/' + experiment)
    else:
        print(model + " doesn't have a " + experiment + " experiment...")
        print('rejected. \n')
        continue

    if frequency in pls:
        pls = os.listdir(CMIP5_dir + '/' + model + '/' + experiment + '/' + frequency)
    else:
        print(model + " doesn't have a " + frequency + " frequency...")
        print('rejected. \n')
        continue

    if medium in pls:
        pls = os.listdir(CMIP5_dir + '/' + model + '/' + experiment + '/' + frequency + '/' + 
            medium)
    else:
        print(model + " doesn't have a " + medium + " medium...")
        print('rejected. \n')
        continue

    if initial_cond in pls:
        pls = os.listdir(CMIP5_dir + '/' + model + '/' + experiment + '/' + frequency + '/' + 
            medium + '/' + initial_cond)
    else:
        print(model + " doesn't have " + initial_cond + " initial conditions...")
        print('rejected. \n')
        continue

    if SST in pls:
        pls = os.listdir(CMIP5_dir + '/' + model + '/' + experiment + '/' + frequency + '/' + 
            medium + '/' + initial_cond  + '/' +  SST)
    else:
        print(model + " doesn't have the " + SST + " variable...")
        print('rejected. \n')
        continue

    if version in pls:
        pls = sorted(os.listdir(CMIP5_dir + '/' + model + '/' + experiment + '/' + frequency + '/' + 
            medium + '/' + initial_cond  + '/' +  SST  + '/' +  version))
    else:
        print(model + " doesn't have a " + version + " version...")
        print('rejected. \n')
        continue

    # The CMIP5 Historical runs should start on January 1850
    if '185001' in pls[0]:
        pass
    else:
        print(model + " starts in " + pls[0][-16:-10] + " and not in January 1850...")
        
        if int(pls[0][-16:-10]) <= start_time:
            print("start time is on or before " + str(start_time) + "...")
            pass
        else:
            print('rejected... \n')
            continue
        

    # And finish in December 2005
    if '200512' in pls[-1]:
        pass
    else:
        print(model + " finishes in " + pls[0][-9:-3] + " and not in December 2005")
        
        if int(pls[0][-9:-3]) > finish_time:
            print("finish time is after " + str(finish_time) + "...")
            pass
        else:
            print('rejected... \n')
            continue
    
    # Because SST is 2D, the data should be in one file
    if len(pls) == 1:
        pass
    else:
        print(model + " has " + str(len(pls)) + " chunks of data and not one")
        print("concatenating into " + my_dir + "...")
        print("passed for now...")
        pass
    
    
    pls = os.listdir(output_path)
    if 
    os.system('ncrcat -v ' \
            + v + ' ' + input_data_path + ' ' + output_data_path)
    
    print(model + " is all good :) ...")
    print("Copying into " + my_dir + "...")
    print('\n')

    

    #print pls
# Out:
# ACCESS1-0 is all good :) ...
# Copying into /g/data/e14/erd561/CMIP5...
#
#
# ACCESS1-3 is all good :) ...
# Copying into /g/data/e14/erd561/CMIP5...
#
#
# BESM-OA2-3 doesn't have a historical experiment...
# rejected.
#
# BNU-ESM is all good :) ...
# Copying into /g/data/e14/erd561/CMIP5...
#
#
# CCSM4 is all good :) ...
# Copying into /g/data/e14/erd561/CMIP5...
#
#
# CESM1-BGC is all good :) ...
# Copying into /g/data/e14/erd561/CMIP5...
#
#
# CESM1-CAM5 is all good :) ...
# Copying into /g/data/e14/erd561/CMIP5...
#
#
# CESM1-CAM5-1-FV2 is all good :) ...
# Copying into /g/data/e14/erd561/CMIP5...
#
#
# CESM1-FASTCHEM is all good :) ...
# Copying into /g/data/e14/erd561/CMIP5...
#
#
# CESM1-WACCM is all good :) ...
# Copying into /g/data/e14/erd561/CMIP5...
#
#
# CFSv2-2011 doesn't have a historical experiment...
# rejected.
#
# CMCC-CESM has 26 chunks of data and not one
# Concatenating into /g/data/e14/erd561/CMIP5...
# CMCC-CESM is all good :) ...
# Copying into /g/data/e14/erd561/CMIP5...
#
#
# CMCC-CM has 16 chunks of data and not one
# Concatenating into /g/data/e14/erd561/CMIP5...
# CMCC-CM is all good :) ...
# Copying into /g/data/e14/erd561/CMIP5...
#
#
# CMCC-CMS has 16 chunks of data and not one
# Concatenating into /g/data/e14/erd561/CMIP5...
# CMCC-CMS is all good :) ...
# Copying into /g/data/e14/erd561/CMIP5...
#
#
# CNRM-CM5 has 16 chunks of data and not one
# Concatenating into /g/data/e14/erd561/CMIP5...
# CNRM-CM5 is all good :) ...
# Copying into /g/data/e14/erd561/CMIP5...
#
#
# CNRM-CM5-2 has 16 chunks of data and not one
# Concatenating into /g/data/e14/erd561/CMIP5...
# CNRM-CM5-2 is all good :) ...
# Copying into /g/data/e14/erd561/CMIP5...
#
#
# COSMOS-ASO doesn't have a historical experiment...
# rejected.
#
# CSIRO-Mk3-6-0 is all good :) ...
# Copying into /g/data/e14/erd561/CMIP5...
#
#
# CSIRO-Mk3L-1-2 doesn't have r1i1p1 initial conditions...
# rejected.
#
# CanAM4 doesn't have a historical experiment...
# rejected.
#
# CanCM4 starts in 196101 and not in January 1850...
# rejected...
#
# CanESM2 is all good :) ...
# Copying into /g/data/e14/erd561/CMIP5...
#
#
# EC-EARTH finishes in 200912 and not in December 2005
# finish time is after 200512...
# EC-EARTH is all good :) ...
# Copying into /g/data/e14/erd561/CMIP5...
#
#
# EC-EARTH-2-2 doesn't have a historical experiment...
# rejected.
#
# FGOALS-g2 has 4 chunks of data and not one
# Concatenating into /g/data/e14/erd561/CMIP5...
# FGOALS-g2 is all good :) ...
# Copying into /g/data/e14/erd561/CMIP5...
#
#
# FGOALS-gl doesn't have a historical experiment...
# rejected.
#
# FGOALS-s2 finishes in 200412 and not in December 2005
# rejected...
#
# FIO-ESM is all good :) ...
# Copying into /g/data/e14/erd561/CMIP5...
#
#
# GEOS-5 doesn't have a historical experiment...
# rejected.
#
# GFDL-CM2p1 starts in 186101 and not in January 1850...
# start time is on or before 186101...
# GFDL-CM2p1 finishes in 186512 and not in December 2005
# rejected...
#
# GFDL-CM3 starts in 186001 and not in January 1850...
# start time is on or before 186101...
# GFDL-CM3 has 30 chunks of data and not one
# Concatenating into /g/data/e14/erd561/CMIP5...
# GFDL-CM3 is all good :) ...
# Copying into /g/data/e14/erd561/CMIP5...
#
#
# GFDL-ESM2G starts in 186101 and not in January 1850...
# start time is on or before 186101...
# GFDL-ESM2G has 29 chunks of data and not one
# Concatenating into /g/data/e14/erd561/CMIP5...
# GFDL-ESM2G is all good :) ...
# Copying into /g/data/e14/erd561/CMIP5...
#
#
# GFDL-ESM2M starts in 186101 and not in January 1850...
# start time is on or before 186101...
# GFDL-ESM2M has 29 chunks of data and not one
# Concatenating into /g/data/e14/erd561/CMIP5...
# GFDL-ESM2M is all good :) ...
# Copying into /g/data/e14/erd561/CMIP5...
#
#
# GFDL-HIRAM-C180 doesn't have a historical experiment...
# rejected.
#
# GFDL-HIRAM-C360 doesn't have a historical experiment...
# rejected.
#
# GISS-E2-H has 3 chunks of data and not one
# Concatenating into /g/data/e14/erd561/CMIP5...
# GISS-E2-H is all good :) ...
# Copying into /g/data/e14/erd561/CMIP5...
#
#
# GISS-E2-H-CC finishes in 190012 and not in December 2005
# rejected...
#
# GISS-E2-R has 7 chunks of data and not one
# Concatenating into /g/data/e14/erd561/CMIP5...
# GISS-E2-R is all good :) ...
# Copying into /g/data/e14/erd561/CMIP5...
#
#
# GISS-E2-R-CC finishes in 187512 and not in December 2005
# rejected...
#
# HadCM3 starts in 185912 and not in January 1850...
# start time is on or before 186101...
# HadCM3 has 6 chunks of data and not one
# Concatenating into /g/data/e14/erd561/CMIP5...
# HadCM3 is all good :) ...
# Copying into /g/data/e14/erd561/CMIP5...
#
#
# HadGEM2-A doesn't have a historical experiment...
# rejected.
#
# HadGEM2-AO starts in 186001 and not in January 1850...
# start time is on or before 186101...
# HadGEM2-AO is all good :) ...
# Copying into /g/data/e14/erd561/CMIP5...
#
#
# HadGEM2-CC starts in 185912 and not in January 1850...
# start time is on or before 186101...
# HadGEM2-CC finishes in 195911 and not in December 2005
# rejected...
#
# HadGEM2-ES starts in 185912 and not in January 1850...
# start time is on or before 186101...
# HadGEM2-ES has 2 chunks of data and not one
# Concatenating into /g/data/e14/erd561/CMIP5...
# HadGEM2-ES is all good :) ...
# Copying into /g/data/e14/erd561/CMIP5...
#
#
# IPSL-CM5A-LR is all good :) ...
# Copying into /g/data/e14/erd561/CMIP5...
#
#
# IPSL-CM5A-MR is all good :) ...
# Copying into /g/data/e14/erd561/CMIP5...
#
#
# IPSL-CM5B-LR is all good :) ...
# Copying into /g/data/e14/erd561/CMIP5...
#
#
# KCM1-2-2 doesn't have a historical experiment...
# rejected.
#
# MIROC-ESM is all good :) ...
# Copying into /g/data/e14/erd561/CMIP5...
#
#
# MIROC-ESM-CHEM is all good :) ...
# Copying into /g/data/e14/erd561/CMIP5...
#
#
# MIROC4h doesn't have the tos variable...
# rejected.
#
# MIROC5 finishes in 201212 and not in December 2005
# finish time is after 200512...
# MIROC5 is all good :) ...
# Copying into /g/data/e14/erd561/CMIP5...
#
#
# MPI-ESM-LR is all good :) ...
# Copying into /g/data/e14/erd561/CMIP5...
#
#
# MPI-ESM-MR has 3 chunks of data and not one
# Concatenating into /g/data/e14/erd561/CMIP5...
# MPI-ESM-MR is all good :) ...
# Copying into /g/data/e14/erd561/CMIP5...
#
#
# MPI-ESM-P is all good :) ...
# Copying into /g/data/e14/erd561/CMIP5...
#
#
# MRI-AGCM3-2H doesn't have a historical experiment...
# rejected.
#
# MRI-AGCM3-2S doesn't have a historical experiment...
# rejected.
#
# MRI-CGCM3 is all good :) ...
# Copying into /g/data/e14/erd561/CMIP5...
#
#
# MRI-ESM1 starts in 185101 and not in January 1850...
# start time is on or before 186101...
# MRI-ESM1 is all good :) ...
# Copying into /g/data/e14/erd561/CMIP5...
#
#
# NorESM1-M is all good :) ...
# Copying into /g/data/e14/erd561/CMIP5...
#
#
# NorESM1-ME is all good :) ...
# Copying into /g/data/e14/erd561/CMIP5...
#
#
# ULAQ doesn't have a historical experiment...
# rejected.
#
# bcc-csm1-1 finishes in 201212 and not in December 2005
# finish time is after 200512...
# bcc-csm1-1 is all good :) ...
# Copying into /g/data/e14/erd561/CMIP5...
#
#
# bcc-csm1-1-m finishes in 201212 and not in December 2005
# finish time is after 200512...
# bcc-csm1-1-m is all good :) ...
# Copying into /g/data/e14/erd561/CMIP5...
#
#
# inmcm4 is all good :) ...
# Copying into /g/data/e14/erd561/CMIP5...
